# %%
import numpy as np
import pandas as pd

# %%
deliveries_df = pd.read_csv('/content/drive/MyDrive/diminos_data_v2/deliveries.csv')
deliveries_df
# Out:
#           order_id                     time_stamp            status
# 0        321230114  2020-12-11 00:01:29.000000000           Pending
# 1        321230114  2020-12-11 00:06:29.000000000  Out For Delivery
# 2        321230114  2020-12-11 00:19:13.299151076         Delivered
# 3        321230115  2020-12-11 00:36:02.000000000           Pending
# 4        321230115  2020-12-11 00:41:02.000000000  Out For Delivery
# ...            ...                            ...               ...
# 1363003  321684446  2024-01-31 23:58:08.494812502         Delivered
# 1363004  321684449  2024-02-01 00:00:46.000000000  Out For Delivery
# 1363005  321684448  2024-02-01 00:03:05.000000000  Out For Delivery
# 1363006  321684449  2024-02-01 00:14:56.997433391         Delivered
# 1363007  321684448  2024-02-01 00:17:50.996900711         Delivered
#
# [1363008 rows x 3 columns]

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363008 entries, 0 to 1363007
# Data columns (total 3 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   order_id    1363008 non-null  int64
#  1   time_stamp  1363008 non-null  object
#  2   status      1363008 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 31.2+ MB

# %%
deliveries_df['status'].unique()
# Out:
# array(['Pending', 'Out For Delivery', 'Delivered'], dtype=object)

# %%
deliveries_df['time_stamp']=pd.to_datetime(deliveries_df['time_stamp'])

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363008 entries, 0 to 1363007
# Data columns (total 3 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   order_id    1363008 non-null  int64
#  1   time_stamp  1363008 non-null  datetime64[ns]
#  2   status      1363008 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 31.2+ MB

# %%
deliveries_df.head()
# Out:
#     order_id                    time_stamp            status
# 0  321230114 2020-12-11 00:01:29.000000000           Pending
# 1  321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# 2  321230114 2020-12-11 00:19:13.299151076         Delivered
# 3  321230115 2020-12-11 00:36:02.000000000           Pending
# 4  321230115 2020-12-11 00:41:02.000000000  Out For Delivery

# %%
deliveries_df.shape
# Out:
# (1363008, 3)

# %%
deliveries_df.isnull().sum()
# Out:
# order_id      0
# time_stamp    0
# status        0
# dtype: int64

# %%
order_items_df = pd.read_csv('/content/drive/MyDrive/diminos_data_v2/order_items.csv')
order_items_df
# Out:
#          order_id                items_ordered
# 0       321230114  ['p_025', 'p_032', 'p_037']
# 1       321230115           ['p_017', 'p_012']
# 2       321230116           ['p_027', 'p_037']
# 3       321230117           ['p_004', 'p_029']
# 4       321230118           ['p_017', 'p_037']
# ...           ...                          ...
# 454331  321684445  ['p_002', 'p_006', 'p_037']
# 454332  321684446           ['p_015', 'p_013']
# 454333  321684447           ['p_009', 'p_016']
# 454334  321684448  ['p_007', 'p_003', 'p_037']
# 454335  321684449           ['p_022', 'p_037']
#
# [454336 rows x 2 columns]

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454336 entries, 0 to 454335
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_id       454336 non-null  int64
#  1   items_ordered  454336 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ MB

# %%
order_items_df.shape
# Out:
# (454336, 2)

# %%
order_items_df.isnull().sum()
# Out:
# order_id         0
# items_ordered    0
# dtype: int64

# %%
order_items_df.head()
# Out:
#     order_id                items_ordered
# 0  321230114  ['p_025', 'p_032', 'p_037']
# 1  321230115           ['p_017', 'p_012']
# 2  321230116           ['p_027', 'p_037']
# 3  321230117           ['p_004', 'p_029']
# 4  321230118           ['p_017', 'p_037']

# %%
orders_df=pd.read_csv('/content/drive/MyDrive/diminos_data_v2/orders.csv')
orders_df
# Out:
#          order_id      order_placed_at
# 0       321230114  2020-12-11 00:01:29
# 1       321230115  2020-12-11 00:36:02
# 2       321230116  2020-12-11 00:55:01
# 3       321230117  2020-12-11 01:05:27
# 4       321230118  2020-12-11 01:14:20
# ...           ...                  ...
# 454331  321684445  2024-01-31 23:27:51
# 454332  321684446  2024-01-31 23:40:14
# 454333  321684447  2024-01-31 23:36:08
# 454334  321684448  2024-01-31 23:58:05
# 454335  321684449  2024-01-31 23:55:46
#
# [454336 rows x 2 columns]

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454336 entries, 0 to 454335
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   order_id         454336 non-null  int64
#  1   order_placed_at  454336 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.9+ MB

# %%
orders_df['order_placed_at']=pd.to_datetime(orders_df['order_placed_at'])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454336 entries, 0 to 454335
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   order_id         454336 non-null  int64
#  1   order_placed_at  454336 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 6.9 MB

# %%
orders_df.shape
# Out:
# (454336, 2)

# %%
orders_df.isnull().sum()
# Out:
# order_id           0
# order_placed_at    0
# dtype: int64

# %%
products_df=pd.read_csv('/content/drive/MyDrive/diminos_data_v2/products.csv')
products_df
# Out:
#    item_id category                      Item     Size  Price
# 0    p_001      Veg                Margherita  Regular    109
# 1    p_002      Veg                Margherita   Medium    245
# 2    p_003      Veg                Margherita    Large    455
# 3    p_004      Veg  Double Cheese Margherita  Regular    215
# 4    p_005      Veg  Double Cheese Margherita   Medium    385
# 5    p_006      Veg  Double Cheese Margherita    Large    619
# 6    p_007      Veg                Farm House  Regular    265
# 7    p_008      Veg                Farm House   Medium    469
# 8    p_009      Veg                Farm House    Large    705
# 9    p_010      Veg             Deluxe Veggie  Regular    219
# 10   p_011      Veg             Deluxe Veggie   Medium    385
# 11   p_012      Veg             Deluxe Veggie    Large    619
# 12   p_013      Veg             Cheese N Corn  Regular    179
# 13   p_014      Veg             Cheese N Corn   Medium    319
# ...

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   37 non-null     object
#  1   category  37 non-null     object
#  2   Item      37 non-null     object
#  3   Size      37 non-null     object
#  4   Price     37 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.6+ KB

# %%
products_df.shape
# Out:
# (37, 5)

# %%
products_df.isnull().sum()
# Out:
# item_id     0
# category    0
# Item        0
# Size        0
# Price       0
# dtype: int64

# %%
products_df.head()
# Out:
#   item_id category                      Item     Size  Price
# 0   p_001      Veg                Margherita  Regular    109
# 1   p_002      Veg                Margherita   Medium    245
# 2   p_003      Veg                Margherita    Large    455
# 3   p_004      Veg  Double Cheese Margherita  Regular    215
# 4   p_005      Veg  Double Cheese Margherita   Medium    385

# %% [markdown]
# What is the average Delivery Time (in minutes) taken by the store to deliver the Pizza?
#
# Round off the answer upto 2 decimal places

# %%
merged_deliveries_and_order_items_and_orders_df=pd.merge(deliveries_df,order_items_df, on='order_id').merge(orders_df,on='order_id')
merged_deliveries_and_order_items_and_orders_df
# Out:
#           order_id                    time_stamp            status  \
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 1        321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# 2        321230114 2020-12-11 00:19:13.299151076         Delivered
# 3        321230115 2020-12-11 00:36:02.000000000           Pending
# 4        321230115 2020-12-11 00:41:02.000000000  Out For Delivery
# ...            ...                           ...               ...
# 1363003  321684449 2024-02-01 00:00:46.000000000  Out For Delivery
# 1363004  321684449 2024-02-01 00:14:56.997433391         Delivered
# 1363005  321684448 2024-01-31 23:58:05.000000000           Pending
# 1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#                        items_ordered     order_placed_at
# 0        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29
# ...

# %%
merged_deliveries_and_order_items_and_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1363008 entries, 0 to 1363007
# Data columns (total 5 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   order_id         1363008 non-null  int64
#  1   time_stamp       1363008 non-null  datetime64[ns]
#  2   status           1363008 non-null  object
#  3   items_ordered    1363008 non-null  object
#  4   order_placed_at  1363008 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 62.4+ MB

# %%
delivered_df=merged_deliveries_and_order_items_and_orders_df[merged_deliveries_and_order_items_and_orders_df['status'] == 'Delivered']
delivered_df
# Out:
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# 1362998  321684447 2024-01-31 23:56:35.426400154  Delivered
# 1363001  321684446 2024-01-31 23:58:08.494812502  Delivered
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#                        items_ordered     order_placed_at
# 2        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29
# 5                 ['p_017', 'p_012'] 2020-12-11 00:36:02
# 8                 ['p_027', 'p_037'] 2020-12-11 00:55:01
# ...

# %%
delivered_df['timestamp_minutes']=delivered_df['time_stamp'].dt.minute
delivered_df['timestamp_minutes']
# Out:
# <ipython-input-880-7b74497af265>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['timestamp_minutes']=delivered_df['time_stamp'].dt.minute
# 2          19
# 5          59
# 8          13
# 11         22
# 14         32
#            ..
# 1362995    45
# 1362998    56
# 1363001    58
# 1363004    14
# 1363007    17
# Name: timestamp_minutes, Length: 454336, dtype: int64

# %%
delivered_df['timestamp_hours']=delivered_df['time_stamp'].dt.hour
delivered_df['timestamp_hours']
# Out:
# <ipython-input-881-c07a11c65216>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['timestamp_hours']=delivered_df['time_stamp'].dt.hour
# 2           0
# 5           0
# 8           1
# 11          1
# 14          1
#            ..
# 1362995    23
# 1362998    23
# 1363001    23
# 1363004     0
# 1363007     0
# Name: timestamp_hours, Length: 454336, dtype: int64

# %%
delivered_df['timestamp_total_minutes']=delivered_df['timestamp_hours'] * 60 + delivered_df['timestamp_minutes']
delivered_df['timestamp_total_minutes']
# Out:
# <ipython-input-882-8db3c0965ad6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['timestamp_total_minutes']=delivered_df['timestamp_hours'] * 60 + delivered_df['timestamp_minutes']
# 2            19
# 5            59
# 8            73
# 11           82
# 14           92
#            ...
# 1362995    1425
# 1362998    1436
# 1363001    1438
# 1363004      14
# 1363007      17
# Name: timestamp_total_minutes, Length: 454336, dtype: int64

# %%
delivered_df
# Out:
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# 1362998  321684447 2024-01-31 23:56:35.426400154  Delivered
# 1363001  321684446 2024-01-31 23:58:08.494812502  Delivered
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#                        items_ordered     order_placed_at  timestamp_minutes  \
# 2        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29                 19
# 5                 ['p_017', 'p_012'] 2020-12-11 00:36:02                 59
# ...

# %%
delivered_df['order_placed_minutes']=delivered_df['order_placed_at'].dt.minute
delivered_df['order_placed_minutes']
# Out:
# <ipython-input-884-9e4d42d1772f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['order_placed_minutes']=delivered_df['order_placed_at'].dt.minute
# 2           1
# 5          36
# 8          55
# 11          5
# 14         14
#            ..
# 1362995    27
# 1362998    36
# 1363001    40
# 1363004    55
# 1363007    58
# Name: order_placed_minutes, Length: 454336, dtype: int64

# %%
delivered_df['order_placed_hour']=delivered_df['order_placed_at'].dt.hour
delivered_df['order_placed_hour']
# Out:
# <ipython-input-885-a6ab36949ae0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['order_placed_hour']=delivered_df['order_placed_at'].dt.hour
# 2           0
# 5           0
# 8           0
# 11          1
# 14          1
#            ..
# 1362995    23
# 1362998    23
# 1363001    23
# 1363004    23
# 1363007    23
# Name: order_placed_hour, Length: 454336, dtype: int64

# %%
delivered_df['order_placed_total_minutes']=delivered_df['order_placed_hour'] * 60 + delivered_df['order_placed_minutes']
delivered_df['order_placed_total_minutes']
# Out:
# <ipython-input-886-00fbdb772240>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['order_placed_total_minutes']=delivered_df['order_placed_hour'] * 60 + delivered_df['order_placed_minutes']
# 2             1
# 5            36
# 8            55
# 11           65
# 14           74
#            ...
# 1362995    1407
# 1362998    1416
# 1363001    1420
# 1363004    1435
# 1363007    1438
# Name: order_placed_total_minutes, Length: 454336, dtype: int64

# %%
delivered_df
# Out:
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# 1362998  321684447 2024-01-31 23:56:35.426400154  Delivered
# 1363001  321684446 2024-01-31 23:58:08.494812502  Delivered
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#                        items_ordered     order_placed_at  timestamp_minutes  \
# 2        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29                 19
# 5                 ['p_017', 'p_012'] 2020-12-11 00:36:02                 59
# ...

# %%
delivered_df['delivery_time_minutes']=delivered_df['timestamp_total_minutes'] - delivered_df['order_placed_total_minutes']
delivered_df['delivery_time_minutes']
# Out:
# <ipython-input-888-94ad34391668>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['delivery_time_minutes']=delivered_df['timestamp_total_minutes'] - delivered_df['order_placed_total_minutes']
# 2            18
# 5            23
# 8            18
# 11           17
# 14           18
#            ...
# 1362995      18
# 1362998      20
# 1363001      18
# 1363004   -1421
# 1363007   -1421
# Name: delivery_time_minutes, Length: 454336, dtype: int64

# %%
delivered_df
# Out:
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# 1362998  321684447 2024-01-31 23:56:35.426400154  Delivered
# 1363001  321684446 2024-01-31 23:58:08.494812502  Delivered
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#                        items_ordered     order_placed_at  timestamp_minutes  \
# 2        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29                 19
# 5                 ['p_017', 'p_012'] 2020-12-11 00:36:02                 59
# ...

# %%
delivered_df['delivery_time_minutes'].describe()
# Out:
# count    454336.000000
# mean          9.128546
# std         128.231930
# min       -1424.000000
# 25%          19.000000
# 50%          20.000000
# 75%          22.000000
# max          63.000000
# Name: delivery_time_minutes, dtype: float64

# %%
avg_delivery_time=delivered_df['delivery_time_minutes'].mean()
avg_delivery_time
# Out:
# 9.12854583392027

# %%
rounded_number = round(avg_delivery_time, 2)
print(rounded_number)
# Out:
# 9.13

# %%
delivered_df['delivery_time_minutes'].describe()
# Out:
# count    454336.000000
# mean          9.128546
# std         128.231930
# min       -1424.000000
# 25%          19.000000
# 50%          20.000000
# 75%          22.000000
# max          63.000000
# Name: delivery_time_minutes, dtype: float64

# %%
delivery_times = delivered_df['delivery_time_minutes']

percentile_99 = np.percentile(delivery_times, 99)

print("99th percentile Delivery Time (in minutes):", percentile_99)
# Out:
# 99th percentile Delivery Time (in minutes): 31.0

# %%
delivery_times = delivered_df['delivery_time_minutes']

percentile_95 = np.percentile(delivery_times, 95)

print("95th percentile Delivery Time (in minutes):", percentile_95)
# Out:
# 95th percentile Delivery Time (in minutes): 26.0

# %%
delivered_df['delivery_time_minutes'].describe()
# Out:
# count    454336.000000
# mean          9.128546
# std         128.231930
# min       -1424.000000
# 25%          19.000000
# 50%          20.000000
# 75%          22.000000
# max          63.000000
# Name: delivery_time_minutes, dtype: float64

# %%
order_id_highest_delivery_time=delivered_df[delivered_df['delivery_time_minutes'] == 63]
order_id_highest_delivery_time
# Out:
#           order_id                    time_stamp     status  \
# 1196819  321629049 2023-09-21 16:52:49.724687723  Delivered
#
#                        items_ordered     order_placed_at  timestamp_minutes  \
# 1196819  ['p_022', 'p_029', 'p_037'] 2023-09-21 15:49:55                 52
#
#          timestamp_hours  timestamp_total_minutes  order_placed_minutes  \
# 1196819               16                     1012                    49
#
#          order_placed_hour  order_placed_total_minutes  delivery_time_minutes
# 1196819                 15                         949                     63

# %%
order_id_highest_delivery_time['order_id']
# Out:
# 1196819    321629049
# Name: order_id, dtype: int64

# %%
merged_deliveries_and_order_items_and_orders_df["items_ordered"] = merged_deliveries_and_order_items_and_orders_df["items_ordered"].apply(eval)

# %%
merged_deliveries_and_order_items_and_orders_df=merged_deliveries_and_order_items_and_orders_df.explode('items_ordered')
merged_deliveries_and_order_items_and_orders_df
# Out:
#           order_id                    time_stamp            status  \
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 1        321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# 1        321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# ...            ...                           ...               ...
# 1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#         items_ordered     order_placed_at
# 0               p_025 2020-12-11 00:01:29
# 0               p_032 2020-12-11 00:01:29
# ...

# %%
merged_deliveries_and_order_items_and_orders_df['timestamp_date'] = merged_deliveries_and_order_items_and_orders_df['time_stamp'].dt.date

# %%
merged_deliveries_and_order_items_and_orders_df['order_placed_at_date'] = merged_deliveries_and_order_items_and_orders_df['order_placed_at'].dt.date

# %%
merged_deliveries_and_order_items_and_orders_df
# Out:
#           order_id                    time_stamp            status  \
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 0        321230114 2020-12-11 00:01:29.000000000           Pending
# 1        321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# 1        321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# ...            ...                           ...               ...
# 1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#         items_ordered     order_placed_at timestamp_date order_placed_at_date
# 0               p_025 2020-12-11 00:01:29     2020-12-11           2020-12-11
# ...

# %%
merged_deliveries_and_order_items_and_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3476679 entries, 0 to 1363007
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   order_id              int64
#  1   time_stamp            datetime64[ns]
#  2   status                object
#  3   items_ordered         object
#  4   order_placed_at       datetime64[ns]
#  5   timestamp_date        object
#  6   order_placed_at_date  object
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 212.2+ MB

# %%
merged_deliveries_and_order_items_and_orders_df['timestamp_date']=pd.to_datetime(merged_deliveries_and_order_items_and_orders_df['timestamp_date'])

# %%
merged_deliveries_and_order_items_and_orders_df['order_placed_at_date']=pd.to_datetime(merged_deliveries_and_order_items_and_orders_df['order_placed_at_date'])

# %%
merged_deliveries_and_order_items_and_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3476679 entries, 0 to 1363007
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   order_id              int64
#  1   time_stamp            datetime64[ns]
#  2   status                object
#  3   items_ordered         object
#  4   order_placed_at       datetime64[ns]
#  5   timestamp_date        datetime64[ns]
#  6   order_placed_at_date  datetime64[ns]
# dtypes: datetime64[ns](4), int64(1), object(2)
# memory usage: 212.2+ MB

# %%
merged_deliveries_and_order_items_and_orders_df.columns
# Out:
# Index(['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at',
#        'timestamp_date', 'order_placed_at_date'],
#       dtype='object')

# %%
january_data =[merged_deliveries_and_order_items_and_orders_df[(merged_deliveries_and_order_items_and_orders_df['order_placed_at_date'] >= '2024-01-01') & (merged_deliveries_and_order_items_and_orders_df['order_placed_at_date'] <= '2024-01-31')]]
january_data
# Out:
# [          order_id                    time_stamp            status  \
#  1326096  321672146 2024-01-01 00:02:30.000000000           Pending
#  1326096  321672146 2024-01-01 00:02:30.000000000           Pending
#  1326097  321672146 2024-01-01 00:07:30.000000000  Out For Delivery
#  1326097  321672146 2024-01-01 00:07:30.000000000  Out For Delivery
#  1326098  321672146 2024-01-01 00:21:44.105365820         Delivered
#  ...            ...                           ...               ...
#  1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
#  1363006  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
#  1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
#  1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
#  1363007  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#          items_ordered     order_placed_at timestamp_date order_placed_at_date
# ...

# %%
january_data_array = np.array(january_data)

# %%
january_data_reshaped = january_data_array.reshape(-1, 7)

# %%
column_names = ['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at','timestamp_date', 'order_placed_at_date']
january_df = pd.DataFrame(january_data_reshaped,columns=column_names)

# %%
january_df
# Out:
#         order_id                    time_stamp            status  \
# 0      321672146 2024-01-01 00:02:30.000000000           Pending
# 1      321672146 2024-01-01 00:02:30.000000000           Pending
# 2      321672146 2024-01-01 00:07:30.000000000  Out For Delivery
# 3      321672146 2024-01-01 00:07:30.000000000  Out For Delivery
# 4      321672146 2024-01-01 00:21:44.105365820         Delivered
# ...          ...                           ...               ...
# 94069  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 94070  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 94071  321684448 2024-02-01 00:17:50.996900711         Delivered
# 94072  321684448 2024-02-01 00:17:50.996900711         Delivered
# 94073  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#       items_ordered     order_placed_at timestamp_date order_placed_at_date
# 0             p_020 2024-01-01 00:02:30     2024-01-01           2024-01-01
# ...

# %%
coke_january_df=january_df[january_df['items_ordered'] == 'p_037']
coke_january_df
# Out:
#         order_id                    time_stamp            status  \
# 1      321672146 2024-01-01 00:02:30.000000000           Pending
# 3      321672146 2024-01-01 00:07:30.000000000  Out For Delivery
# 5      321672146 2024-01-01 00:21:44.105365820         Delivered
# 8      321672147 2024-01-01 00:08:01.000000000           Pending
# 11     321672147 2024-01-01 00:13:01.000000000  Out For Delivery
# ...          ...                           ...               ...
# 94062  321684449 2024-02-01 00:00:46.000000000  Out For Delivery
# 94064  321684449 2024-02-01 00:14:56.997433391         Delivered
# 94067  321684448 2024-01-31 23:58:05.000000000           Pending
# 94070  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 94073  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#       items_ordered     order_placed_at timestamp_date order_placed_at_date
# 1             p_037 2024-01-01 00:02:30     2024-01-01           2024-01-01
# ...

# %%
94074-31221
# Out:
# 62853

# %%
january_delivery_df= january_df[january_df['status'] == 'Delivered']
january_delivery_df
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 4      321672146 2024-01-01 00:21:44.105365820  Delivered         p_020
# 5      321672146 2024-01-01 00:21:44.105365820  Delivered         p_037
# 12     321672147 2024-01-01 00:31:05.366818534  Delivered         p_004
# 13     321672147 2024-01-01 00:31:05.366818534  Delivered         p_031
# 14     321672147 2024-01-01 00:31:05.366818534  Delivered         p_037
# ...          ...                           ...        ...           ...
# 94063  321684449 2024-02-01 00:14:56.997433391  Delivered         p_022
# 94064  321684449 2024-02-01 00:14:56.997433391  Delivered         p_037
# 94071  321684448 2024-02-01 00:17:50.996900711  Delivered         p_007
# 94072  321684448 2024-02-01 00:17:50.996900711  Delivered         p_003
# 94073  321684448 2024-02-01 00:17:50.996900711  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date
# ...

# %%
january_delivery_df['timestamp_minutes']=january_delivery_df['time_stamp'].dt.minute
january_delivery_df['timestamp_hours']=january_delivery_df['time_stamp'].dt.hour
january_delivery_df['timestamp_total_minutes']=january_delivery_df['timestamp_hours'] * 60 + january_delivery_df['timestamp_minutes']

january_delivery_df['order_placed_at_minutes']=january_delivery_df['order_placed_at'].dt.minute
january_delivery_df['order_placed_at_hours']=january_delivery_df['order_placed_at'].dt.hour
january_delivery_df['order_placed_at_total_minutes']=january_delivery_df['order_placed_at_hours'] * 60 + january_delivery_df['order_placed_at_minutes']
# Out:
# <ipython-input-917-ae05346b7836>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_delivery_df['timestamp_minutes']=january_delivery_df['time_stamp'].dt.minute
# <ipython-input-917-ae05346b7836>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_delivery_df['timestamp_hours']=january_delivery_df['time_stamp'].dt.hour
# <ipython-input-917-ae05346b7836>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
january_delivery_df['timestamp_total_seconds'] = january_delivery_df['time_stamp'].dt.hour * 3600 + january_delivery_df['time_stamp'].dt.minute * 60 + january_delivery_df['time_stamp'].dt.second
january_delivery_df['order_placed_at_total_seconds'] = january_delivery_df['order_placed_at'].dt.hour * 3600 + january_delivery_df['order_placed_at'].dt.minute * 60 + january_delivery_df['order_placed_at'].dt.second
# Out:
# <ipython-input-918-3154e97580d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_delivery_df['timestamp_total_seconds'] = january_delivery_df['time_stamp'].dt.hour * 3600 + january_delivery_df['time_stamp'].dt.minute * 60 + january_delivery_df['time_stamp'].dt.second
# <ipython-input-918-3154e97580d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
january_delivery_df
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 4      321672146 2024-01-01 00:21:44.105365820  Delivered         p_020
# 5      321672146 2024-01-01 00:21:44.105365820  Delivered         p_037
# 12     321672147 2024-01-01 00:31:05.366818534  Delivered         p_004
# 13     321672147 2024-01-01 00:31:05.366818534  Delivered         p_031
# 14     321672147 2024-01-01 00:31:05.366818534  Delivered         p_037
# ...          ...                           ...        ...           ...
# 94063  321684449 2024-02-01 00:14:56.997433391  Delivered         p_022
# 94064  321684449 2024-02-01 00:14:56.997433391  Delivered         p_037
# 94071  321684448 2024-02-01 00:17:50.996900711  Delivered         p_007
# 94072  321684448 2024-02-01 00:17:50.996900711  Delivered         p_003
# 94073  321684448 2024-02-01 00:17:50.996900711  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
january_delivery_df['delivery_time_minutes']=january_delivery_df['timestamp_total_minutes'] - january_delivery_df['order_placed_at_total_minutes']
january_delivery_df['delivery_time_minutes']
# Out:
# <ipython-input-920-e94859fa00e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_delivery_df['delivery_time_minutes']=january_delivery_df['timestamp_total_minutes'] - january_delivery_df['order_placed_at_total_minutes']
# 4          19
# 5          19
# 12         23
# 13         23
# 14         23
#          ...
# 94063   -1421
# 94064   -1421
# 94071   -1421
# 94072   -1421
# 94073   -1421
# Name: delivery_time_minutes, Length: 31358, dtype: int64

# %%
january_delivery_df['delivery_time_seconds']=january_delivery_df['timestamp_total_seconds'] - january_delivery_df['order_placed_at_total_seconds']
january_delivery_df['delivery_time_seconds']
# Out:
# <ipython-input-921-0e968d14a10d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   january_delivery_df['delivery_time_seconds']=january_delivery_df['timestamp_total_seconds'] - january_delivery_df['order_placed_at_total_seconds']
# 4         1154
# 5         1154
# 12        1384
# 13        1384
# 14        1384
#          ...
# 94063   -85250
# 94064   -85250
# 94071   -85215
# 94072   -85215
# 94073   -85215
# Name: delivery_time_seconds, Length: 31358, dtype: int64

# %%
january_delivery_df
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 4      321672146 2024-01-01 00:21:44.105365820  Delivered         p_020
# 5      321672146 2024-01-01 00:21:44.105365820  Delivered         p_037
# 12     321672147 2024-01-01 00:31:05.366818534  Delivered         p_004
# 13     321672147 2024-01-01 00:31:05.366818534  Delivered         p_031
# 14     321672147 2024-01-01 00:31:05.366818534  Delivered         p_037
# ...          ...                           ...        ...           ...
# 94063  321684449 2024-02-01 00:14:56.997433391  Delivered         p_022
# 94064  321684449 2024-02-01 00:14:56.997433391  Delivered         p_037
# 94071  321684448 2024-02-01 00:17:50.996900711  Delivered         p_007
# 94072  321684448 2024-02-01 00:17:50.996900711  Delivered         p_003
# 94073  321684448 2024-02-01 00:17:50.996900711  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
more_than_30_minutes_df=january_delivery_df[january_delivery_df['delivery_time_seconds'] > 1800]
more_than_30_minutes_df
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 579    321672219 2024-01-01 07:40:00.050788143  Delivered         p_002
# 580    321672219 2024-01-01 07:40:00.050788143  Delivered         p_004
# 581    321672219 2024-01-01 07:40:00.050788143  Delivered         p_037
# 793    321672246 2024-01-01 10:42:08.274877203  Delivered         p_018
# 794    321672246 2024-01-01 10:42:08.274877203  Delivered         p_037
# ...          ...                           ...        ...           ...
# 93553  321684378 2024-01-31 18:35:39.707616698  Delivered         p_016
# 93554  321684378 2024-01-31 18:35:39.707616698  Delivered         p_037
# 93912  321684428 2024-01-31 21:40:13.177156302  Delivered         p_024
# 93913  321684428 2024-01-31 21:40:13.177156302  Delivered         p_011
# 93914  321684428 2024-01-31 21:40:13.177156302  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
more_than_30_minutes_df.describe()
# Out:
#        timestamp_minutes  timestamp_hours  timestamp_total_minutes  \
# count         412.000000       412.000000               412.000000
# mean           31.106796        13.456311               838.485437
# std            18.038031         5.598100               335.292758
# min             0.000000         0.000000                51.000000
# 25%            14.000000         9.000000               592.000000
# 50%            32.000000        14.000000               854.000000
# 75%            47.000000        17.000000              1077.000000
# max            59.000000        23.000000              1439.000000
#
#        order_placed_at_minutes  order_placed_at_hours  \
# count               412.000000             412.000000
# mean                 27.104369              12.968447
# std                  16.472237               5.563740
# min                   0.000000               0.000000
# 25%                  13.000000               9.000000
# ...

# %%
refund_2023_data=[merged_deliveries_and_order_items_and_orders_df[(merged_deliveries_and_order_items_and_orders_df['time_stamp'] >= '2023-01-01') & (merged_deliveries_and_order_items_and_orders_df['time_stamp'] <= '2023-12-31')]]
refund_2023_data
# Out:
# [          order_id                    time_stamp            status  \
#  871499   321520613 2023-01-01 00:07:33.244922300         Delivered
#  871499   321520613 2023-01-01 00:07:33.244922300         Delivered
#  871502   321520615 2023-01-01 00:06:16.751226144         Delivered
#  871502   321520615 2023-01-01 00:06:16.751226144         Delivered
#  871505   321520614 2023-01-01 00:07:13.392937318         Delivered
#  ...            ...                           ...               ...
#  1324861  321671734 2023-12-30 23:33:33.000000000  Out For Delivery
#  1324861  321671734 2023-12-30 23:33:33.000000000  Out For Delivery
#  1324862  321671734 2023-12-30 23:48:37.298491391         Delivered
#  1324862  321671734 2023-12-30 23:48:37.298491391         Delivered
#  1324862  321671734 2023-12-30 23:48:37.298491391         Delivered
#
#          items_ordered     order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2023_data_array = np.array(refund_2023_data)

# %%
refund_2023_data_reshaped = refund_2023_data_array.reshape(-1, 7)

# %%
column_names = ['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at','timestamp_date', 'order_placed_at_date']
refund_2023_data = pd.DataFrame(refund_2023_data_reshaped,columns=column_names)

# %%
refund_2023_data
# Out:
#           order_id                    time_stamp            status  \
# 0        321520613 2023-01-01 00:07:33.244922300         Delivered
# 1        321520613 2023-01-01 00:07:33.244922300         Delivered
# 2        321520615 2023-01-01 00:06:16.751226144         Delivered
# 3        321520615 2023-01-01 00:06:16.751226144         Delivered
# 4        321520614 2023-01-01 00:07:13.392937318         Delivered
# ...            ...                           ...               ...
# 1156483  321671734 2023-12-30 23:33:33.000000000  Out For Delivery
# 1156484  321671734 2023-12-30 23:33:33.000000000  Out For Delivery
# 1156485  321671734 2023-12-30 23:48:37.298491391         Delivered
# 1156486  321671734 2023-12-30 23:48:37.298491391         Delivered
# 1156487  321671734 2023-12-30 23:48:37.298491391         Delivered
#
#         items_ordered     order_placed_at timestamp_date order_placed_at_date
# 0               p_030 2022-12-31 23:45:10     2023-01-01           2022-12-31
# ...

# %%
refund_2023_df=refund_2023_data[refund_2023_data['status'] == 'Delivered']
refund_2023_df
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 0        321520613 2023-01-01 00:07:33.244922300  Delivered         p_030
# 1        321520613 2023-01-01 00:07:33.244922300  Delivered         p_037
# 2        321520615 2023-01-01 00:06:16.751226144  Delivered         p_031
# 3        321520615 2023-01-01 00:06:16.751226144  Delivered         p_037
# 4        321520614 2023-01-01 00:07:13.392937318  Delivered         p_005
# ...            ...                           ...        ...           ...
# 1156477  321671733 2023-12-30 23:38:42.949542772  Delivered         p_008
# 1156478  321671733 2023-12-30 23:38:42.949542772  Delivered         p_037
# 1156485  321671734 2023-12-30 23:48:37.298491391  Delivered         p_012
# 1156486  321671734 2023-12-30 23:48:37.298491391  Delivered         p_033
# 1156487  321671734 2023-12-30 23:48:37.298491391  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2023_df['timestamp_total_seconds'] = refund_2023_df['time_stamp'].dt.hour * 3600 +refund_2023_df['time_stamp'].dt.minute * 60 + refund_2023_df['time_stamp'].dt.second
refund_2023_df['order_placed_at_total_seconds'] = refund_2023_df['order_placed_at'].dt.hour * 3600 + refund_2023_df['order_placed_at'].dt.minute * 60 + refund_2023_df['order_placed_at'].dt.second
# Out:
# <ipython-input-931-ede426ab915f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refund_2023_df['timestamp_total_seconds'] = refund_2023_df['time_stamp'].dt.hour * 3600 +refund_2023_df['time_stamp'].dt.minute * 60 + refund_2023_df['time_stamp'].dt.second
# <ipython-input-931-ede426ab915f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
refund_2023_df['delivery_time_seconds']=refund_2023_df['timestamp_total_seconds'] - refund_2023_df['order_placed_at_total_seconds']
refund_2023_df['delivery_time_seconds']
# Out:
# <ipython-input-932-ae685b5a5235>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refund_2023_df['delivery_time_seconds']=refund_2023_df['timestamp_total_seconds'] - refund_2023_df['order_placed_at_total_seconds']
# 0         -85057
# 1         -85057
# 2         -85292
# 3         -85292
# 4         -85359
#            ...
# 1156477     1081
# 1156478     1081
# 1156485     1204
# 1156486     1204
# 1156487     1204
# Name: delivery_time_seconds, Length: 385505, dtype: int64

# %%
refund_2023_df
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 0        321520613 2023-01-01 00:07:33.244922300  Delivered         p_030
# 1        321520613 2023-01-01 00:07:33.244922300  Delivered         p_037
# 2        321520615 2023-01-01 00:06:16.751226144  Delivered         p_031
# 3        321520615 2023-01-01 00:06:16.751226144  Delivered         p_037
# 4        321520614 2023-01-01 00:07:13.392937318  Delivered         p_005
# ...            ...                           ...        ...           ...
# 1156477  321671733 2023-12-30 23:38:42.949542772  Delivered         p_008
# 1156478  321671733 2023-12-30 23:38:42.949542772  Delivered         p_037
# 1156485  321671734 2023-12-30 23:48:37.298491391  Delivered         p_012
# 1156486  321671734 2023-12-30 23:48:37.298491391  Delivered         p_033
# 1156487  321671734 2023-12-30 23:48:37.298491391  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
amount_lost_refund_2023=refund_2023_df[refund_2023_df['delivery_time_seconds']>1800]
amount_lost_refund_2023
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 726      321520710 2023-01-01 07:13:53.796142791  Delivered         p_020
# 727      321520710 2023-01-01 07:13:53.796142791  Delivered         p_030
# 728      321520710 2023-01-01 07:13:53.796142791  Delivered         p_037
# 1267     321520781 2023-01-01 12:21:27.548250439  Delivered         p_003
# 1268     321520781 2023-01-01 12:21:27.548250439  Delivered         p_023
# ...            ...                           ...        ...           ...
# 1155337  321671580 2023-12-30 13:14:25.962782791  Delivered         p_019
# 1155338  321671580 2023-12-30 13:14:25.962782791  Delivered         p_037
# 1156131  321671686 2023-12-30 18:51:55.304404170  Delivered         p_005
# 1156132  321671686 2023-12-30 18:51:55.304404170  Delivered         p_021
# 1156133  321671686 2023-12-30 18:51:55.304404170  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
products_df
# Out:
#    item_id category                      Item     Size  Price
# 0    p_001      Veg                Margherita  Regular    109
# 1    p_002      Veg                Margherita   Medium    245
# 2    p_003      Veg                Margherita    Large    455
# 3    p_004      Veg  Double Cheese Margherita  Regular    215
# 4    p_005      Veg  Double Cheese Margherita   Medium    385
# 5    p_006      Veg  Double Cheese Margherita    Large    619
# 6    p_007      Veg                Farm House  Regular    265
# 7    p_008      Veg                Farm House   Medium    469
# 8    p_009      Veg                Farm House    Large    705
# 9    p_010      Veg             Deluxe Veggie  Regular    219
# 10   p_011      Veg             Deluxe Veggie   Medium    385
# 11   p_012      Veg             Deluxe Veggie    Large    619
# 12   p_013      Veg             Cheese N Corn  Regular    179
# 13   p_014      Veg             Cheese N Corn   Medium    319
# ...

# %%
products_df.rename(columns={'item_id': 'items_ordered'}, inplace=True)
products_df
# Out:
#    items_ordered category                      Item     Size  Price
# 0          p_001      Veg                Margherita  Regular    109
# 1          p_002      Veg                Margherita   Medium    245
# 2          p_003      Veg                Margherita    Large    455
# 3          p_004      Veg  Double Cheese Margherita  Regular    215
# 4          p_005      Veg  Double Cheese Margherita   Medium    385
# 5          p_006      Veg  Double Cheese Margherita    Large    619
# 6          p_007      Veg                Farm House  Regular    265
# 7          p_008      Veg                Farm House   Medium    469
# 8          p_009      Veg                Farm House    Large    705
# 9          p_010      Veg             Deluxe Veggie  Regular    219
# 10         p_011      Veg             Deluxe Veggie   Medium    385
# 11         p_012      Veg             Deluxe Veggie    Large    619
# 12         p_013      Veg             Cheese N Corn  Regular    179
# ...

# %%
merge_products_amount_lost_refund_2023_df=pd.merge(products_df,amount_lost_refund_2023,on='items_ordered')
merge_products_amount_lost_refund_2023_df
# Out:
#      items_ordered category        Item     Size  Price   order_id  \
# 0            p_001      Veg  Margherita  Regular    109  321521733
# 1            p_001      Veg  Margherita  Regular    109  321525289
# 2            p_001      Veg  Margherita  Regular    109  321526411
# 3            p_001      Veg  Margherita  Regular    109  321528386
# 4            p_001      Veg  Margherita  Regular    109  321530166
# ...            ...      ...         ...      ...    ...        ...
# 4979         p_037      Veg        Coke  Regular     71  321671422
# 4980         p_037      Veg        Coke  Regular     71  321671491
# 4981         p_037      Veg        Coke  Regular     71  321671520
# 4982         p_037      Veg        Coke  Regular     71  321671580
# 4983         p_037      Veg        Coke  Regular     71  321671686
#
#                         time_stamp     status     order_placed_at  \
# 0    2023-01-03 12:04:30.921600753  Delivered 2023-01-03 11:33:58
# ...

# %%
merge_products_amount_lost_refund_2023_df['delivery_time_seconds'].describe()
# Out:
# count    4984.000000
# mean     1991.863965
# std       203.847930
# min      1801.000000
# 25%      1853.000000
# 50%      1927.000000
# 75%      2064.000000
# max      3774.000000
# Name: delivery_time_seconds, dtype: float64

# %%
merge_products_amount_lost_refund_2023_df['Price'].sum()
# Out:
# 1782224

# %% [markdown]
# In 2023 -- 1782224

# %%
refund_2024_data=[merged_deliveries_and_order_items_and_orders_df[(merged_deliveries_and_order_items_and_orders_df['time_stamp'] >= '2024-01-01') & (merged_deliveries_and_order_items_and_orders_df['time_stamp'] <= '2024-12-31')]]
refund_2024_data

refund_2024_data_array = np.array(refund_2024_data)
refund_2024_data_reshaped = refund_2024_data_array.reshape(-1, 7)
column_names = ['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at','timestamp_date', 'order_placed_at_date']
refund_2024_data = pd.DataFrame(refund_2024_data_reshaped,columns=column_names)
refund_2024_data
# Out:
#         order_id                    time_stamp            status  \
# 0      321672139 2024-01-01 00:06:13.918901293         Delivered
# 1      321672139 2024-01-01 00:06:13.918901293         Delivered
# 2      321672139 2024-01-01 00:06:13.918901293         Delivered
# 3      321672140 2024-01-01 00:07:42.538413397         Delivered
# 4      321672140 2024-01-01 00:07:42.538413397         Delivered
# ...          ...                           ...               ...
# 94090  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 94091  321684448 2024-02-01 00:03:05.000000000  Out For Delivery
# 94092  321684448 2024-02-01 00:17:50.996900711         Delivered
# 94093  321684448 2024-02-01 00:17:50.996900711         Delivered
# 94094  321684448 2024-02-01 00:17:50.996900711         Delivered
#
#       items_ordered     order_placed_at timestamp_date order_placed_at_date
# 0             p_004 2023-12-31 23:47:02     2024-01-01           2023-12-31
# ...

# %%
refund_2024_df=refund_2024_data[refund_2024_data['status'] == 'Delivered']
refund_2024_df
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 0      321672139 2024-01-01 00:06:13.918901293  Delivered         p_004
# 1      321672139 2024-01-01 00:06:13.918901293  Delivered         p_015
# 2      321672139 2024-01-01 00:06:13.918901293  Delivered         p_037
# 3      321672140 2024-01-01 00:07:42.538413397  Delivered         p_023
# 4      321672140 2024-01-01 00:07:42.538413397  Delivered         p_003
# ...          ...                           ...        ...           ...
# 94084  321684449 2024-02-01 00:14:56.997433391  Delivered         p_022
# 94085  321684449 2024-02-01 00:14:56.997433391  Delivered         p_037
# 94092  321684448 2024-02-01 00:17:50.996900711  Delivered         p_007
# 94093  321684448 2024-02-01 00:17:50.996900711  Delivered         p_003
# 94094  321684448 2024-02-01 00:17:50.996900711  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2024_df['timestamp_total_seconds'] = refund_2024_df['time_stamp'].dt.hour * 3600 +refund_2024_df['time_stamp'].dt.minute * 60 + refund_2024_df['time_stamp'].dt.second
refund_2024_df['order_placed_at_total_seconds'] = refund_2024_df['order_placed_at'].dt.hour * 3600 + refund_2024_df['order_placed_at'].dt.minute * 60 + refund_2024_df['order_placed_at'].dt.second

refund_2024_df['delivery_time_seconds']=refund_2024_df['timestamp_total_seconds'] - refund_2024_df['order_placed_at_total_seconds']
refund_2024_df['delivery_time_seconds']
refund_2024_df
# Out:
# <ipython-input-942-fd9d0a21d48d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refund_2024_df['timestamp_total_seconds'] = refund_2024_df['time_stamp'].dt.hour * 3600 +refund_2024_df['time_stamp'].dt.minute * 60 + refund_2024_df['time_stamp'].dt.second
# <ipython-input-942-fd9d0a21d48d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
amount_lost_refund_2024=refund_2024_df[refund_2024_df['delivery_time_seconds']>1800]
amount_lost_refund_2024
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 600    321672219 2024-01-01 07:40:00.050788143  Delivered         p_002
# 601    321672219 2024-01-01 07:40:00.050788143  Delivered         p_004
# 602    321672219 2024-01-01 07:40:00.050788143  Delivered         p_037
# 814    321672246 2024-01-01 10:42:08.274877203  Delivered         p_018
# 815    321672246 2024-01-01 10:42:08.274877203  Delivered         p_037
# ...          ...                           ...        ...           ...
# 93574  321684378 2024-01-31 18:35:39.707616698  Delivered         p_016
# 93575  321684378 2024-01-31 18:35:39.707616698  Delivered         p_037
# 93933  321684428 2024-01-31 21:40:13.177156302  Delivered         p_024
# 93934  321684428 2024-01-31 21:40:13.177156302  Delivered         p_011
# 93935  321684428 2024-01-31 21:40:13.177156302  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
merge_products_amount_lost_refund_2024_df=pd.merge(products_df,amount_lost_refund_2024,on='items_ordered')
merge_products_amount_lost_refund_2024_df
# Out:
#     items_ordered category        Item     Size  Price   order_id  \
# 0           p_001      Veg  Margherita  Regular    109  321672885
# 1           p_001      Veg  Margherita  Regular    109  321673592
# 2           p_001      Veg  Margherita  Regular    109  321676145
# 3           p_001      Veg  Margherita  Regular    109  321678538
# 4           p_001      Veg  Margherita  Regular    109  321680198
# ..            ...      ...         ...      ...    ...        ...
# 407         p_037      Veg        Coke  Regular     71  321683988
# 408         p_037      Veg        Coke  Regular     71  321684028
# 409         p_037      Veg        Coke  Regular     71  321684128
# 410         p_037      Veg        Coke  Regular     71  321684378
# 411         p_037      Veg        Coke  Regular     71  321684428
#
#                        time_stamp     status     order_placed_at  \
# 0   2024-01-03 09:36:50.054615198  Delivered 2024-01-03 09:05:47
# ...

# %%
merge_products_amount_lost_refund_2024_df['delivery_time_seconds'].describe()
# Out:
# count     412.000000
# mean     1997.565534
# std       212.913581
# min      1802.000000
# 25%      1846.250000
# 50%      1933.000000
# 75%      2073.000000
# max      2981.000000
# Name: delivery_time_seconds, dtype: float64

# %%
merge_products_amount_lost_refund_2024_df['Price'].sum()
# Out:
# 144890

# %% [markdown]
# In 2024 -- 144890

# %%
refund_2020_data=[merged_deliveries_and_order_items_and_orders_df[(merged_deliveries_and_order_items_and_orders_df['time_stamp'] >= '2020-01-01') & (merged_deliveries_and_order_items_and_orders_df['time_stamp'] <= '2020-12-31')]]
refund_2020_data

refund_2020_data_array = np.array(refund_2020_data)
refund_2020_data_reshaped = refund_2020_data_array.reshape(-1, 7)
column_names = ['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at','timestamp_date', 'order_placed_at_date']
refund_2020_data = pd.DataFrame(refund_2020_data_reshaped,columns=column_names)
refund_2020_data
# Out:
#         order_id                    time_stamp            status  \
# 0      321230114 2020-12-11 00:01:29.000000000           Pending
# 1      321230114 2020-12-11 00:01:29.000000000           Pending
# 2      321230114 2020-12-11 00:01:29.000000000           Pending
# 3      321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# 4      321230114 2020-12-11 00:06:29.000000000  Out For Delivery
# ...          ...                           ...               ...
# 57361  321237601 2020-12-30 23:40:11.000000000  Out For Delivery
# 57362  321237601 2020-12-30 23:40:11.000000000  Out For Delivery
# 57363  321237601 2020-12-30 23:54:16.206409665         Delivered
# 57364  321237601 2020-12-30 23:54:16.206409665         Delivered
# 57365  321237601 2020-12-30 23:54:16.206409665         Delivered
#
#       items_ordered     order_placed_at timestamp_date order_placed_at_date
# 0             p_025 2020-12-11 00:01:29     2020-12-11           2020-12-11
# ...

# %%
refund_2020_df=refund_2020_data[refund_2020_data['status'] == 'Delivered']
refund_2020_df
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 6      321230114 2020-12-11 00:19:13.299151076  Delivered         p_025
# 7      321230114 2020-12-11 00:19:13.299151076  Delivered         p_032
# 8      321230114 2020-12-11 00:19:13.299151076  Delivered         p_037
# 13     321230115 2020-12-11 00:59:18.054846609  Delivered         p_017
# 14     321230115 2020-12-11 00:59:18.054846609  Delivered         p_012
# ...          ...                           ...        ...           ...
# 57353  321237599 2020-12-30 23:41:17.058343848  Delivered         p_031
# 57356  321237600 2020-12-30 23:30:16.737462553  Delivered         p_007
# 57363  321237601 2020-12-30 23:54:16.206409665  Delivered         p_013
# 57364  321237601 2020-12-30 23:54:16.206409665  Delivered         p_014
# 57365  321237601 2020-12-30 23:54:16.206409665  Delivered         p_037
#
#           order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2020_df['timestamp_total_seconds'] = refund_2020_df['time_stamp'].dt.hour * 3600 +refund_2020_df['time_stamp'].dt.minute * 60 + refund_2020_df['time_stamp'].dt.second
refund_2020_df['order_placed_at_total_seconds'] = refund_2020_df['order_placed_at'].dt.hour * 3600 + refund_2020_df['order_placed_at'].dt.minute * 60 + refund_2020_df['order_placed_at'].dt.second

refund_2020_df['delivery_time_seconds']=refund_2020_df['timestamp_total_seconds'] - refund_2020_df['order_placed_at_total_seconds']
refund_2020_df['delivery_time_seconds']
refund_2020_df
# Out:
# <ipython-input-949-e475431dc4dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refund_2020_df['timestamp_total_seconds'] = refund_2020_df['time_stamp'].dt.hour * 3600 +refund_2020_df['time_stamp'].dt.minute * 60 + refund_2020_df['time_stamp'].dt.second
# <ipython-input-949-e475431dc4dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
amount_lost_refund_2020=refund_2020_df[refund_2020_df['delivery_time_seconds']>1800]
amount_lost_refund_2020
# Out:
#         order_id                    time_stamp     status items_ordered  \
# 186    321230138 2020-12-11 05:08:28.711036623  Delivered         p_021
# 187    321230138 2020-12-11 05:08:28.711036623  Delivered         p_001
# 188    321230138 2020-12-11 05:08:28.711036623  Delivered         p_037
# 1474   321230308 2020-12-11 15:27:30.793171773  Delivered         p_027
# 1475   321230308 2020-12-11 15:27:30.793171773  Delivered         p_011
# ...          ...                           ...        ...           ...
# 55974  321237423 2020-12-30 14:25:08.531749212  Delivered         p_002
# 55975  321237423 2020-12-30 14:25:08.531749212  Delivered         p_028
# 55976  321237423 2020-12-30 14:25:08.531749212  Delivered         p_037
# 57352  321237599 2020-12-30 23:41:17.058343848  Delivered         p_019
# 57353  321237599 2020-12-30 23:41:17.058343848  Delivered         p_031
#
#           order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
merge_products_amount_lost_refund_2020_df=pd.merge(products_df,amount_lost_refund_2020,on='items_ordered')
merge_products_amount_lost_refund_2020_df
# Out:
#     items_ordered category        Item     Size  Price   order_id  \
# 0           p_001      Veg  Margherita  Regular    109  321230138
# 1           p_001      Veg  Margherita  Regular    109  321231363
# 2           p_001      Veg  Margherita  Regular    109  321232344
# 3           p_001      Veg  Margherita  Regular    109  321232491
# 4           p_001      Veg  Margherita  Regular    109  321236362
# ..            ...      ...         ...      ...    ...        ...
# 262         p_037      Veg        Coke  Regular     71  321237119
# 263         p_037      Veg        Coke  Regular     71  321237175
# 264         p_037      Veg        Coke  Regular     71  321237264
# 265         p_037      Veg        Coke  Regular     71  321237410
# 266         p_037      Veg        Coke  Regular     71  321237423
#
#                        time_stamp     status     order_placed_at  \
# 0   2020-12-11 05:08:28.711036623  Delivered 2020-12-11 04:38:11
# ...

# %%
merge_products_amount_lost_refund_2020_df['delivery_time_seconds'].describe()
# Out:
# count     267.000000
# mean     1975.382022
# std       199.713282
# min      1801.000000
# 25%      1840.000000
# 50%      1909.000000
# 75%      2033.000000
# max      3074.000000
# Name: delivery_time_seconds, dtype: float64

# %%
merge_products_amount_lost_refund_2020_df['Price'].sum()
# Out:
# 91837

# %% [markdown]
# In 2020 -- 91837

# %%
refund_2021_data=[merged_deliveries_and_order_items_and_orders_df[(merged_deliveries_and_order_items_and_orders_df['time_stamp'] >= '2021-01-01') & (merged_deliveries_and_order_items_and_orders_df['time_stamp'] <= '2021-12-31')]]
refund_2021_data

refund_2021_data_array = np.array(refund_2021_data)
refund_2021_data_reshaped = refund_2021_data_array.reshape(-1, 7)
column_names = ['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at','timestamp_date', 'order_placed_at_date']
refund_2021_data = pd.DataFrame(refund_2021_data_reshaped,columns=column_names)
refund_2021_data
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 0        321237910 2021-01-01 00:00:35.024429659  Delivered         p_019
# 1        321237910 2021-01-01 00:00:35.024429659  Delivered         p_011
# 2        321237910 2021-01-01 00:00:35.024429659  Delivered         p_037
# 3        321237912 2021-01-01 00:02:16.282864797  Delivered         p_007
# 4        321237912 2021-01-01 00:02:16.282864797  Delivered         p_030
# ...            ...                           ...        ...           ...
# 1086557  321379918 2021-12-30 23:55:07.000000000    Pending         p_003
# 1086558  321379918 2021-12-30 23:55:07.000000000    Pending         p_037
# 1086559  321379919 2021-12-30 23:56:49.000000000    Pending         p_029
# 1086560  321379919 2021-12-30 23:56:49.000000000    Pending         p_036
# 1086561  321379919 2021-12-30 23:56:49.000000000    Pending         p_037
#
#             order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2021_df=refund_2021_data[refund_2021_data['status'] == 'Delivered']
refund_2021_df
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 0        321237910 2021-01-01 00:00:35.024429659  Delivered         p_019
# 1        321237910 2021-01-01 00:00:35.024429659  Delivered         p_011
# 2        321237910 2021-01-01 00:00:35.024429659  Delivered         p_037
# 3        321237912 2021-01-01 00:02:16.282864797  Delivered         p_007
# 4        321237912 2021-01-01 00:02:16.282864797  Delivered         p_030
# ...            ...                           ...        ...           ...
# 1086532  321379913 2021-12-30 23:59:12.081080698  Delivered         p_031
# 1086533  321379913 2021-12-30 23:59:12.081080698  Delivered         p_037
# 1086540  321379915 2021-12-30 23:57:59.202805538  Delivered         p_034
# 1086541  321379915 2021-12-30 23:57:59.202805538  Delivered         p_013
# 1086542  321379915 2021-12-30 23:57:59.202805538  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2021_df['timestamp_total_seconds'] = refund_2021_df['time_stamp'].dt.hour * 3600 +refund_2021_df['time_stamp'].dt.minute * 60 + refund_2021_df['time_stamp'].dt.second
refund_2021_df['order_placed_at_total_seconds'] = refund_2021_df['order_placed_at'].dt.hour * 3600 + refund_2021_df['order_placed_at'].dt.minute * 60 + refund_2021_df['order_placed_at'].dt.second

refund_2021_df['delivery_time_seconds']=refund_2021_df['timestamp_total_seconds'] - refund_2021_df['order_placed_at_total_seconds']
refund_2021_df['delivery_time_seconds']
refund_2021_df
# Out:
# <ipython-input-956-ffb8606db25e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refund_2021_df['timestamp_total_seconds'] = refund_2021_df['time_stamp'].dt.hour * 3600 +refund_2021_df['time_stamp'].dt.minute * 60 + refund_2021_df['time_stamp'].dt.second
# <ipython-input-956-ffb8606db25e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
amount_lost_refund_2021=refund_2021_df[refund_2021_df['delivery_time_seconds']>1800]
amount_lost_refund_2021
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 117      321237929 2021-01-01 01:26:30.967116899  Delivered         p_001
# 118      321237929 2021-01-01 01:26:30.967116899  Delivered         p_011
# 119      321237929 2021-01-01 01:26:30.967116899  Delivered         p_037
# 1215     321238076 2021-01-01 16:01:42.350280834  Delivered         p_019
# 1216     321238076 2021-01-01 16:01:42.350280834  Delivered         p_003
# ...            ...                           ...        ...           ...
# 1084988  321379705 2021-12-30 13:35:08.817017432  Delivered         p_037
# 1085767  321379807 2021-12-30 17:39:43.081201805  Delivered         p_036
# 1085768  321379807 2021-12-30 17:39:43.081201805  Delivered         p_037
# 1086358  321379890 2021-12-30 22:32:32.421217389  Delivered         p_033
# 1086359  321379890 2021-12-30 22:32:32.421217389  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
merge_products_amount_lost_refund_2021_df=pd.merge(products_df,amount_lost_refund_2021,on='items_ordered')
merge_products_amount_lost_refund_2021_df
# Out:
#      items_ordered category        Item     Size  Price   order_id  \
# 0            p_001      Veg  Margherita  Regular    109  321237929
# 1            p_001      Veg  Margherita  Regular    109  321239218
# 2            p_001      Veg  Margherita  Regular    109  321243463
# 3            p_001      Veg  Margherita  Regular    109  321243934
# 4            p_001      Veg  Margherita  Regular    109  321243968
# ...            ...      ...         ...      ...    ...        ...
# 4945         p_037      Veg        Coke  Regular     71  321379621
# 4946         p_037      Veg        Coke  Regular     71  321379695
# 4947         p_037      Veg        Coke  Regular     71  321379705
# 4948         p_037      Veg        Coke  Regular     71  321379807
# 4949         p_037      Veg        Coke  Regular     71  321379890
#
#                         time_stamp     status     order_placed_at  \
# 0    2021-01-01 01:26:30.967116899  Delivered 2021-01-01 00:47:38
# ...

# %%
merge_products_amount_lost_refund_2021_df['delivery_time_seconds'].describe()
# Out:
# count    4950.000000
# mean     1993.034141
# std       210.178586
# min      1801.000000
# 25%      1853.000000
# 50%      1930.000000
# 75%      2059.000000
# max      3484.000000
# Name: delivery_time_seconds, dtype: float64

# %%
merge_products_amount_lost_refund_2021_df['Price'].sum()
# Out:
# 1747244

# %% [markdown]
# In 2021-- 1747244

# %%
refund_2022_data=[merged_deliveries_and_order_items_and_orders_df[(merged_deliveries_and_order_items_and_orders_df['time_stamp'] >= '2022-01-01') & (merged_deliveries_and_order_items_and_orders_df['time_stamp'] <= '2022-12-31')]]
refund_2022_data

refund_2022_data_array = np.array(refund_2022_data)
refund_2022_data_reshaped = refund_2022_data_array.reshape(-1, 7)
column_names = ['order_id', 'time_stamp', 'status', 'items_ordered', 'order_placed_at','timestamp_date', 'order_placed_at_date']
refund_2022_data = pd.DataFrame(refund_2022_data_reshaped,columns=column_names)
refund_2022_data
# Out:
#           order_id                    time_stamp            status  \
# 0        321380274 2022-01-01 00:07:34.547507639         Delivered
# 1        321380274 2022-01-01 00:07:34.547507639         Delivered
# 2        321380275 2022-01-01 00:09:22.843140564         Delivered
# 3        321380275 2022-01-01 00:09:22.843140564         Delivered
# 4        321380275 2022-01-01 00:09:22.843140564         Delivered
# ...            ...                           ...               ...
# 1070905  321520223 2022-12-30 23:45:36.000000000  Out For Delivery
# 1070906  321520226 2022-12-30 23:47:28.000000000           Pending
# 1070907  321520226 2022-12-30 23:47:28.000000000           Pending
# 1070908  321520226 2022-12-30 23:52:28.000000000  Out For Delivery
# 1070909  321520226 2022-12-30 23:52:28.000000000  Out For Delivery
#
#         items_ordered     order_placed_at timestamp_date order_placed_at_date
# 0               p_020 2021-12-31 23:45:47     2022-01-01           2021-12-31
# ...

# %%
refund_2022_df=refund_2022_data[refund_2022_data['status'] == 'Delivered']
refund_2022_df
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 0        321380274 2022-01-01 00:07:34.547507639  Delivered         p_020
# 1        321380274 2022-01-01 00:07:34.547507639  Delivered         p_037
# 2        321380275 2022-01-01 00:09:22.843140564  Delivered         p_008
# 3        321380275 2022-01-01 00:09:22.843140564  Delivered         p_032
# 4        321380275 2022-01-01 00:09:22.843140564  Delivered         p_037
# ...            ...                           ...        ...           ...
# 1070891  321520225 2022-12-30 23:56:54.515268197  Delivered         p_022
# 1070892  321520225 2022-12-30 23:56:54.515268197  Delivered         p_026
# 1070893  321520225 2022-12-30 23:56:54.515268197  Delivered         p_037
# 1070898  321520224 2022-12-30 23:58:16.347302834  Delivered         p_001
# 1070899  321520224 2022-12-30 23:58:16.347302834  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date
# ...

# %%
refund_2022_df['timestamp_total_seconds'] = refund_2022_df['time_stamp'].dt.hour * 3600 +refund_2022_df['time_stamp'].dt.minute * 60 + refund_2022_df['time_stamp'].dt.second
refund_2022_df['order_placed_at_total_seconds'] = refund_2022_df['order_placed_at'].dt.hour * 3600 + refund_2022_df['order_placed_at'].dt.minute * 60 + refund_2022_df['order_placed_at'].dt.second

refund_2022_df['delivery_time_seconds']=refund_2022_df['timestamp_total_seconds'] - refund_2022_df['order_placed_at_total_seconds']
refund_2022_df['delivery_time_seconds']
refund_2022_df
# Out:
# <ipython-input-963-1ba57fa1353d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refund_2022_df['timestamp_total_seconds'] = refund_2022_df['time_stamp'].dt.hour * 3600 +refund_2022_df['time_stamp'].dt.minute * 60 + refund_2022_df['time_stamp'].dt.second
# <ipython-input-963-1ba57fa1353d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
amount_lost_refund_2022=refund_2022_df[refund_2022_df['delivery_time_seconds']>1800]
amount_lost_refund_2022
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 1381     321380452 2022-01-01 13:47:06.655786644  Delivered         p_026
# 3006     321380666 2022-01-02 11:07:35.574624130  Delivered         p_030
# 3007     321380666 2022-01-02 11:07:35.574624130  Delivered         p_037
# 3513     321380734 2022-01-02 14:49:14.591101226  Delivered         p_009
# 3514     321380734 2022-01-02 14:49:14.591101226  Delivered         p_037
# ...            ...                           ...        ...           ...
# 1069690  321520063 2022-12-30 15:16:50.331223829  Delivered         p_037
# 1070550  321520175 2022-12-30 19:56:04.112754065  Delivered         p_033
# 1070551  321520175 2022-12-30 19:56:04.112754065  Delivered         p_037
# 1070598  321520184 2022-12-30 20:17:15.956576956  Delivered         p_028
# 1070599  321520184 2022-12-30 20:17:15.956576956  Delivered         p_037
#
#             order_placed_at timestamp_date order_placed_at_date  \
# ...

# %%
merge_products_amount_lost_refund_2022_df=pd.merge(products_df,amount_lost_refund_2022,on='items_ordered')
merge_products_amount_lost_refund_2022_df
# Out:
#      items_ordered category        Item     Size  Price   order_id  \
# 0            p_001      Veg  Margherita  Regular    109  321381178
# 1            p_001      Veg  Margherita  Regular    109  321384136
# 2            p_001      Veg  Margherita  Regular    109  321384222
# 3            p_001      Veg  Margherita  Regular    109  321387587
# 4            p_001      Veg  Margherita  Regular    109  321390872
# ...            ...      ...         ...      ...    ...        ...
# 4627         p_037      Veg        Coke  Regular     71  321519963
# 4628         p_037      Veg        Coke  Regular     71  321520008
# 4629         p_037      Veg        Coke  Regular     71  321520063
# 4630         p_037      Veg        Coke  Regular     71  321520175
# 4631         p_037      Veg        Coke  Regular     71  321520184
#
#                         time_stamp     status     order_placed_at  \
# 0    2022-01-03 17:11:22.552392863  Delivered 2022-01-03 16:34:59
# ...

# %%
merge_products_amount_lost_refund_2022_df['delivery_time_seconds'].describe()
# Out:
# count    4632.000000
# mean     1988.586788
# std       193.840473
# min      1801.000000
# 25%      1854.000000
# 50%      1929.000000
# 75%      2059.000000
# max      3355.000000
# Name: delivery_time_seconds, dtype: float64

# %%
merge_products_amount_lost_refund_2022_df['Price'].sum()
# Out:
# 1632974

# %% [markdown]
# In 2022 1632974

# %% [markdown]
# In 2023, Pizza store has lost maximum amount due to refunds on late deliveries

# %%
delivered_df
# Out:
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# 1362998  321684447 2024-01-31 23:56:35.426400154  Delivered
# 1363001  321684446 2024-01-31 23:58:08.494812502  Delivered
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#                        items_ordered     order_placed_at  timestamp_minutes  \
# 2        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29                 19
# 5                 ['p_017', 'p_012'] 2020-12-11 00:36:02                 59
# ...

# %%
delivered_df['timestamp_total_seconds'] = delivered_df['time_stamp'].dt.hour * 3600 +delivered_df['time_stamp'].dt.minute * 60 + delivered_df['time_stamp'].dt.second
delivered_df['order_placed_at_total_seconds'] = delivered_df['order_placed_at'].dt.hour * 3600 + delivered_df['order_placed_at'].dt.minute * 60 + delivered_df['order_placed_at'].dt.second
# Out:
# <ipython-input-969-3205973d44cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['timestamp_total_seconds'] = delivered_df['time_stamp'].dt.hour * 3600 +delivered_df['time_stamp'].dt.minute * 60 + delivered_df['time_stamp'].dt.second
# <ipython-input-969-3205973d44cb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
delivered_df['delivery_time_seconds']=delivered_df['timestamp_total_seconds'] - delivered_df['order_placed_at_total_seconds']
delivered_df['delivery_time_seconds']
delivered_df
# Out:
# <ipython-input-970-9bdb114a88cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivered_df['delivery_time_seconds']=delivered_df['timestamp_total_seconds'] - delivered_df['order_placed_at_total_seconds']
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# ...

# %%
revenue_df=delivered_df[delivered_df['delivery_time_seconds']<=1800]
revenue_df
# Out:
#           order_id                    time_stamp     status  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered
# 8        321230116 2020-12-11 01:13:52.153042625  Delivered
# 11       321230117 2020-12-11 01:22:44.430088094  Delivered
# 14       321230118 2020-12-11 01:32:27.488575946  Delivered
# ...            ...                           ...        ...
# 1362995  321684445 2024-01-31 23:45:54.185192716  Delivered
# 1362998  321684447 2024-01-31 23:56:35.426400154  Delivered
# 1363001  321684446 2024-01-31 23:58:08.494812502  Delivered
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered
#
#                        items_ordered     order_placed_at  timestamp_minutes  \
# 2        ['p_025', 'p_032', 'p_037'] 2020-12-11 00:01:29                 19
# 5                 ['p_017', 'p_012'] 2020-12-11 00:36:02                 59
# ...

# %%
revenue_df['delivery_time_seconds'].max()
# Out:
# 1800

# %%
revenue_df["items_ordered"] = revenue_df["items_ordered"].apply(eval)
# Out:
# <ipython-input-978-4908fd5708ff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   revenue_df["items_ordered"] = revenue_df["items_ordered"].apply(eval)

# %%
revenue_df=revenue_df.explode('items_ordered')
revenue_df
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered         p_025
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered         p_032
# 2        321230114 2020-12-11 00:19:13.299151076  Delivered         p_037
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered         p_017
# 5        321230115 2020-12-11 00:59:18.054846609  Delivered         p_012
# ...            ...                           ...        ...           ...
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered         p_022
# 1363004  321684449 2024-02-01 00:14:56.997433391  Delivered         p_037
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered         p_007
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered         p_003
# 1363007  321684448 2024-02-01 00:17:50.996900711  Delivered         p_037
#
#             order_placed_at  timestamp_minutes  timestamp_hours  \
# ...

# %%
merge_revenue_products_df=pd.merge(revenue_df,products_df,on='items_ordered')

# %%
merge_revenue_products_df
# Out:
#           order_id                    time_stamp     status items_ordered  \
# 0        321230114 2020-12-11 00:19:13.299151076  Delivered         p_025
# 1        321230125 2020-12-11 03:24:01.429084233  Delivered         p_025
# 2        321230132 2020-12-11 04:04:51.192638615  Delivered         p_025
# 3        321230136 2020-12-11 04:44:40.175141823  Delivered         p_025
# 4        321230174 2020-12-11 08:22:09.140170569  Delivered         p_025
# ...            ...                           ...        ...           ...
# 1143601  321684344 2024-01-31 17:07:16.198293573  Delivered         p_035
# 1143602  321684386 2024-01-31 18:53:03.984373283  Delivered         p_035
# 1143603  321684398 2024-01-31 19:24:43.512111920  Delivered         p_035
# 1143604  321684401 2024-01-31 19:33:01.304076752  Delivered         p_035
# 1143605  321684410 2024-01-31 20:18:15.167953404  Delivered         p_035
#
#             order_placed_at  timestamp_minutes  timestamp_hours  \
# ...

# %%
merge_revenue_products_df['Price'].sum()
# Out:
# 402419894

# %% [markdown]
# (BONUS QUESTION) Which distribution can be used to model the number of orders incoming each hour? If we can somehow model it, which problem for owner of Pizza Store can be solved?

# %% [markdown]
# Normal distribution can be used to model the number of orders incoming each hour. We as a data scientists can increase company's revenue.
